# %%
# Visualization reqires a special library. It may take a minute to load, so be patient.
library(ggplot2) 
# load data 
df = read.csv("ChinaRegionalData2024.isle.csv", header = TRUE, stringsAsFactors = FALSE, fileEncoding = "UTF-8-BOM")
# Make variabl names accessible 
attach(df)
# Show names of all variables in the data set:
names(df)

# %% [markdown]
# # SZTU Data Science Class Final Exam
#
# Use techniques and templates (SZTU Data Analysis Examples.ipynb) as discussed in class: https://nils-mci.github.io/SZTU26/lab/index.html
#
# Task 1:
#
# 1.	Develop a Question of your choice regarding regional differences in China. Refer to the four major geographical regions of China.
# 2.	Develop a proper hypothesis, use AI to assist you.
# 3.	Operationalize your variable of interest by referring to *ChinaRegionalData2024.isle.xlsx* and describe it by means of descriptive statistics.
# 4.	Provide evidence to support your hypothesis by applying appropriate methods.
# 4.	Describe and interpret your results.
#
# Task 2:
#
# 1.	Develop a second question of your choice regarding the association of your variable with a second variable, use AI to assist you.
# 2.	Develop a proper hypothesis, use AI to assist you.
# 3.	Operationalize your second variable by referring to *ChinaRegionalData2024.isle.xlsx* and describe it by means of descriptive statistics.
# 4.	Provide evidence to support your hypothesis by applying appropriate methods.
# 4.	Describe and interpret your results.
#
# Notes:
#
# - You may work in groups of 2 (recommended).
# - Use AI to assist you with hypothesis building and interpretation, but keep your text short and to the point.
# - Strictly follow the structure of the template we developed in class on Tuesday!
# - **Don’t forget to add your student-ID and real names at the title page!**
# - Save your work to your local harddrive by right clicking your file, select "download" and rename id1 and id2 with your student-IDs (add a single ID if you work alone). Then e-mail your file to me: nils.mevenkamp@mci.edu
# - Submit on **September 30, 2026**, at the latest.
# - **Always download your work before you close your browser window!**
#
# Have fun!

# %% [markdown]
# # My China Data Story

# %% [markdown]
# Student 1: **Type your name and your student-ID here!**
#
# Student 2: **Type your name and your student-ID here! Leave blank if you work alone.**

# %% [markdown]
# # Question 1
